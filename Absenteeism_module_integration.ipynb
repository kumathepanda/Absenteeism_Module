# %%
from absenteeism_predictor import *

# %%
df=pd.read_csv("D:/absenteeism_project/Absenteeism_new_data.csv")
df.head()
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  22                  27  01/06/2018                     179
# 1  10                   7  04/06/2018                     361
# 2  14                  23  06/06/2018                     155
# 3  17                  25  08/06/2018                     179
# 4  14                  10  08/06/2018                     155
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                26   30                  237.656               19          3
# 1                52   28                  237.656               27          1
# 2                12   34                  237.656               25          1
# 3                22   40                  237.656               22          2
# 4                12   34                  237.656               25          1
#
#    Children  Pets
# 0         0     0
# 1         1     4
# 2         2     0
# 3         2     0
# 4         2     0

# %%
model = absenteeism_model("model","scaler")

# %%
model.load_and_clean_data("D:/absenteeism_project/Absenteeism_new_data.csv")

# %%
model.predicted_outputs()
# Out:
#     Transportation Expense  Age  Body Mass Index  Education  Children  Pets  \
# 0                      179   30               19          1         0     0
# 1                      361   28               27          0         1     4
# 2                      155   34               25          0         2     0
# 3                      179   40               22          1         2     0
# 4                      155   34               25          0         2     0
# 5                      225   28               24          0         1     2
# 6                      118   46               25          0         2     0
# 7                      179   30               19          1         0     0
# 8                      118   37               28          0         0     0
# 9                      118   37               28          0         0     0
# 10                     378   36               21          0         2     4
# ...

# %%
model.predicted_outputs().to_csv("Absenteeism_predictions.csv",index=False)
